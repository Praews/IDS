# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Country-data.csv')

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.scatterplot(data = df, x = 'imports', y = 'exports', color = 'g')
# Out:
# <AxesSubplot:xlabel='imports', ylabel='exports'>

# %%
เป็นการพล็อตเพื่อดูความสัมพันธ์ระหว่างสินค้านำเข้ากับสินค้าที่ส่งออกซึ่งจะเห็นได้ว่าสินค้านำเข้าและส่งออกจะไม่ได้มีความแตกต่างกันมากนัก 
ดังนั้นจึงสรุปได้ว่าประเทศได้มีการส่งออกและนำเข้าที่มีปริมาณใกล้เคียงกัน

# %%
sns.scatterplot(data = df, x = 'child_mort', y = 'total_fer')
# Out:
# <AxesSubplot:xlabel='child_mort', ylabel='total_fer'>

# %%
sns.scatterplot(data = df, x = 'income', y = 'gdpp')
# Out:
# <AxesSubplot:xlabel='income', ylabel='gdpp'>

# %%
plt.scatter(data = df, x = 'income', y = 'gdpp',c= 'g')

# %%
เป็นการพล็อตเพื่อดูความสัมพันธ์ระหว่างรายได้กับ gdp โดยมีขอบเขตรายได้ตั้งแต่ 0 ถึง 100,000 เพื่อที่ได้รู้ว่ารายได้เท่านี้จะมี gdp เท่าไหร่
ซึ่งได้รู้ว่ารายได้เท่านี้จะมีรายได้ที่สูงขึ้น ค่า gdp ก็มีแนวโน้มสูงขึ้นตามไปด้วย

# %%
plt.scatter(data = df, x = 'income', y = 'life_expec',c= 'b')
